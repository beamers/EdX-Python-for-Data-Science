# %%
# Data Source: https://www.kaggle.com/worldbank/world-development-indicators
# Folder: 'world-development-indicators'

# %% [markdown]
# <br><p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold">
# Matplotlib: Exploring <br> <br> <br>Data Visualization</p><br><br>

# %% [markdown]
# <br><br><center><h1 style="font-size:2em;color:#2467C0">World Development Indicators</h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="https://upload.wikimedia.org/wikipedia/commons/4/46/North_South_divide.svg" align="middle" style="width:550px;height:360px;"/></td>
# <td>
# This week, we will be using an open dataset from <a href="https://www.kaggle.com">Kaggle</a>. It is  <a href="https://www.kaggle.com/worldbank/world-development-indicators">The World Development Indicators</a> dataset obtained from the World Bank containing over a thousand annual indicators of economic development from hundreds of countries around the world.
# <br>
# <br>
# This is a slightly modified version of the original dataset from <a href="http://data.worldbank.org/data-catalog/world-development-indicators">The World Bank</a>
# <br>
# <br>
# List of the <a href="https://www.kaggle.com/benhamner/d/worldbank/world-development-indicators/indicators-in-data">available indicators</a> and a <a href="https://www.kaggle.com/benhamner/d/worldbank/world-development-indicators/countries-in-the-wdi-data">list of the available countries</a>.
# </td>
# </tr>
# </table>

# %% [markdown]
# # Step 1: Initial exploration of the Dataset

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./world-development-indicators/Indicators.csv')
data.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e681bc9be60c> in <module>
# ----> 1 data = pd.read_csv('./world-development-indicators/Indicators.csv')
#       2 data.shape
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'./world-development-indicators/Indicators.csv' does not exist

# %% [markdown]
# This is a really large dataset, at least in terms of the number of rows.  But with 6 columns, what does this hold?

# %%
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3591102a07a2> in <module>
# ----> 1 data.head(10)
#
# NameError: name 'data' is not defined

# %% [markdown]
# Looks like it has different indicators for different countries with the year and value of the indicator.

# %% [markdown]
# ### How many UNIQUE country names are there ?

# %%
countries = data['CountryName'].unique().tolist()
len(countries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7b91a313bf6e> in <module>
# ----> 1 countries = data['CountryName'].unique().tolist()
#       2 len(countries)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ### Are there same number of country codes ?

# %%
# How many unique country codes are there ? (should be the same #)
countryCodes = data['CountryCode'].unique().tolist()
len(countryCodes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fd3870e9ef84> in <module>
#       1 # How many unique country codes are there ? (should be the same #)
# ----> 2 countryCodes = data['CountryCode'].unique().tolist()
#       3 len(countryCodes)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ### Are there many indicators or few ?

# %%
# How many unique indicators are there ? (should be the same #)
indicators = data['IndicatorName'].unique().tolist()
len(indicators)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9a4e5c93149a> in <module>
#       1 # How many unique indicators are there ? (should be the same #)
# ----> 2 indicators = data['IndicatorName'].unique().tolist()
#       3 len(indicators)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ### How many years of data do we have ?

# %%
# How many years of data do we have ?
years = data['Year'].unique().tolist()
len(years)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c502ccd3e03a> in <module>
#       1 # How many years of data do we have ?
# ----> 2 years = data['Year'].unique().tolist()
#       3 len(years)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ### What's the range of years?

# %%
print(min(years)," to ",max(years))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8c9699125b5d> in <module>
# ----> 1 print(min(years)," to ",max(years))
#
# NameError: name 'years' is not defined

# %% [markdown]
# <p style="font-family: Arial; font-size:2.5em;color:blue; font-style:bold">
# Matplotlib: Basic Plotting, Part 1</p><br>

# %% [markdown]
# ### Lets pick a country and an indicator to explore: CO2 Emissions per capita and the USA

# %%
# select CO2 emissions for the United States
hist_indicator = 'CO2 emissions \(metric'
hist_country = 'USA'

mask1 = data['IndicatorName'].str.contains(hist_indicator) 
mask2 = data['CountryCode'].str.contains(hist_country)

# stage is just those indicators matching the USA for country code and CO2 emissions over time.
stage = data[mask1 & mask2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e6fa30c95501> in <module>
#       3 hist_country = 'USA'
#       4
# ----> 5 mask1 = data['IndicatorName'].str.contains(hist_indicator)
#       6 mask2 = data['CountryCode'].str.contains(hist_country)
#       7
#
# NameError: name 'data' is not defined

# %%
stage.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d4aca370c751> in <module>
# ----> 1 stage.head()
#
# NameError: name 'stage' is not defined

# %% [markdown]
# ### Let's see how emissions have changed over time using MatplotLib

# %%
# get the years
years = stage['Year'].values
# get the values 
co2 = stage['Value'].values

# create
plt.bar(years,co2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b81eed2474fb> in <module>
#       1 # get the years
# ----> 2 years = stage['Year'].values
#       3 # get the values
#       4 co2 = stage['Value'].values
#       5
#
# NameError: name 'stage' is not defined

# %% [markdown]
# Turns out emissions per capita have dropped a bit over time, but let's make this graphic a bit more appealing before we continue to explore it.

# %%
# switch to a line plot
plt.plot(stage['Year'].values, stage['Value'].values)

# Label the axes
plt.xlabel('Year')
plt.ylabel(stage['IndicatorName'].iloc[0])

#label the figure
plt.title('CO2 Emissions in USA')

# to make more honest, start they y axis at 0
plt.axis([1959, 2011,0,25])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1409a388e203> in <module>
#       1 # switch to a line plot
# ----> 2 plt.plot(stage['Year'].values, stage['Value'].values)
#       3
#       4 # Label the axes
#       5 plt.xlabel('Year')
#
# NameError: name 'stage' is not defined

# %% [markdown]
# ### Using Histograms to explore the distribution of values
# We could also visualize this data as a histogram to better explore the ranges of values in CO2 production per year.

# %%
# If you want to just include those within one standard deviation fo the mean, you could do the following
# lower = stage['Value'].mean() - stage['Value'].std()
# upper = stage['Value'].mean() + stage['Value'].std()
# hist_data = [x for x in stage[:10000]['Value'] if x>lower and x<upper ]

# Otherwise, let's look at all the data
hist_data = stage['Value'].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8fa96396b1da> in <module>
#       5
#       6 # Otherwise, let's look at all the data
# ----> 7 hist_data = stage['Value'].values
#
# NameError: name 'stage' is not defined

# %%
print(len(hist_data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-97d3d47e23f9> in <module>
# ----> 1 print(len(hist_data))
#
# NameError: name 'hist_data' is not defined

# %%
# the histogram of the data
plt.hist(hist_data, 10, density=False, facecolor='green')

plt.xlabel(stage['IndicatorName'].iloc[0])
plt.ylabel('# of Years')
plt.title('Histogram Example')

plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-63b29ba46943> in <module>
#       1 # the histogram of the data
# ----> 2 plt.hist(hist_data, 10, density=False, facecolor='green')
#       3
#       4 plt.xlabel(stage['IndicatorName'].iloc[0])
#       5 plt.ylabel('# of Years')
#
# NameError: name 'hist_data' is not defined

# %% [markdown]
# So the USA has many years where it produced between 19-20 metric tons per capita with outliers on either side.

# %% [markdown]
# ### But how do the USA's numbers relate to those of other countries?

# %%
# select CO2 emissions for all countries in 2011
hist_indicator = 'CO2 emissions \(metric'
hist_year = 2011

mask1 = data['IndicatorName'].str.contains(hist_indicator) 
mask2 = data['Year'].isin([hist_year])

# apply our mask
co2_2011 = data[mask1 & mask2]
co2_2011.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-ee98ed8ea9a3> in <module>
#       3 hist_year = 2011
#       4
# ----> 5 mask1 = data['IndicatorName'].str.contains(hist_indicator)
#       6 mask2 = data['Year'].isin([hist_year])
#       7
#
# NameError: name 'data' is not defined

# %% [markdown]
# For how many countries do we have CO2 per capita emissions data in 2011

# %%
print(len(co2_2011))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f12e24bd914c> in <module>
# ----> 1 print(len(co2_2011))
#
# NameError: name 'co2_2011' is not defined

# %%
# let's plot a histogram of the emmissions per capita by country

# subplots returns a touple with the figure, axis attributes.
fig, ax = plt.subplots()

ax.annotate("USA",
            xy=(18, 5), xycoords='data',
            xytext=(18, 30), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

plt.hist(co2_2011['Value'], 10, normed=False, facecolor='green')

plt.xlabel(stage['IndicatorName'].iloc[0])
plt.ylabel('# of Countries')
plt.title('Histogram of CO2 Emissions Per Capita')

#plt.axis([10, 22, 0, 14])
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-702f283dc009> in <module>
#      11             )
#      12
# ---> 13 plt.hist(co2_2011['Value'], 10, normed=False, facecolor='green')
#      14
#      15 plt.xlabel(stage['IndicatorName'].iloc[0])
#
# NameError: name 'co2_2011' is not defined

# %% [markdown]
# So the USA, at ~18 CO2 emissions (metric tons per capital) is quite high among all countries.
#
# An interesting next step, which we'll save for you, would be to explore how this relates to other industrialized nations and to look at the outliers with those values in the 40s!

# %% [markdown]
# <p style="font-family: Arial; font-size:2.0em;color:blue; font-style:bold">
# Matplotlib: Basic Plotting, Part 2</p>

# %% [markdown]
# ### Relationship between GPD and CO2 Emissions in USA

# %%
# select GDP Per capita emissions for the United States
hist_indicator = 'GDP per capita \(constant 2005'
hist_country = 'USA'

mask1 = data['IndicatorName'].str.contains(hist_indicator) 
mask2 = data['CountryCode'].str.contains(hist_country)

# stage is just those indicators matching the USA for country code and CO2 emissions over time.
gdp_stage = data[mask1 & mask2]

#plot gdp_stage vs stage

# %%
gdp_stage.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-123e7d13f931> in <module>
# ----> 1 gdp_stage.head(2)
#
# NameError: name 'gdp_stage' is not defined

# %%
stage.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-3242e96c1623> in <module>
# ----> 1 stage.head(2)
#
# NameError: name 'stage' is not defined

# %%
# switch to a line plot
plt.plot(gdp_stage['Year'].values, gdp_stage['Value'].values)

# Label the axes
plt.xlabel('Year')
plt.ylabel(gdp_stage['IndicatorName'].iloc[0])

#label the figure
plt.title('GDP Per Capita USA')

# to make more honest, start they y axis at 0
#plt.axis([1959, 2011,0,25])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-dbf901e8c629> in <module>
#       1 # switch to a line plot
# ----> 2 plt.plot(gdp_stage['Year'].values, gdp_stage['Value'].values)
#       3
#       4 # Label the axes
#       5 plt.xlabel('Year')
#
# NameError: name 'gdp_stage' is not defined

# %% [markdown]
# So although we've seen a decline in the CO2 emissions per capita, it does not seem to translate to a decline in GDP per capita

# %% [markdown]
# ### ScatterPlot for comparing GDP against CO2 emissions (per capita)
#
# First, we'll need to make sure we're looking at the same time frames

# %%
print("GDP Min Year = ", gdp_stage['Year'].min(), "max: ", gdp_stage['Year'].max())
print("CO2 Min Year = ", stage['Year'].min(), "max: ", stage['Year'].max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-533a5c88b8c7> in <module>
# ----> 1 print("GDP Min Year = ", gdp_stage['Year'].min(), "max: ", gdp_stage['Year'].max())
#       2 print("CO2 Min Year = ", stage['Year'].min(), "max: ", stage['Year'].max())
#
# NameError: name 'gdp_stage' is not defined

# %% [markdown]
# We have 3 extra years of GDP data, so let's trim those off so the scatterplot has equal length arrays to compare (this is actually required by scatterplot)

# %%
gdp_stage_trunc = gdp_stage[gdp_stage['Year'] < 2012]
print(len(gdp_stage_trunc))
print(len(stage))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-50d90086137c> in <module>
# ----> 1 gdp_stage_trunc = gdp_stage[gdp_stage['Year'] < 2012]
#       2 print(len(gdp_stage_trunc))
#       3 print(len(stage))
#
# NameError: name 'gdp_stage' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, axis = plt.subplots()
# Grid lines, Xticks, Xlabel, Ylabel

axis.yaxis.grid(True)
axis.set_title('CO2 Emissions vs. GDP \(per capita\)',fontsize=10)
axis.set_xlabel(gdp_stage_trunc['IndicatorName'].iloc[0],fontsize=10)
axis.set_ylabel(stage['IndicatorName'].iloc[0],fontsize=10)

X = gdp_stage_trunc['Value']
Y = stage['Value']

axis.scatter(X, Y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-9adbf774fb98> in <module>
#       7 axis.yaxis.grid(True)
#       8 axis.set_title('CO2 Emissions vs. GDP \(per capita\)',fontsize=10)
# ----> 9 axis.set_xlabel(gdp_stage_trunc['IndicatorName'].iloc[0],fontsize=10)
#      10 axis.set_ylabel(stage['IndicatorName'].iloc[0],fontsize=10)
#      11
#
# NameError: name 'gdp_stage_trunc' is not defined

# %% [markdown]
# This doesn't look like a strong relationship.  We can test this by looking at correlation.

# %%
np.corrcoef(gdp_stage_trunc['Value'],stage['Value'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-2380c2810b3b> in <module>
# ----> 1 np.corrcoef(gdp_stage_trunc['Value'],stage['Value'])
#
# NameError: name 'gdp_stage_trunc' is not defined

# %% [markdown]
# A correlation of 0.07 is pretty weak, but you'll learn more about correlation in the next course.
#
# You could continue to explore this to see if other countries have a closer relationship between CO2 emissions and GDP.  Perhaps it is stronger for developing countries?

# %% [markdown]
# ## Want more ?
#
# ### Matplotlib Examples Library

# %% [markdown]
# http://matplotlib.org/examples/index.html

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;
